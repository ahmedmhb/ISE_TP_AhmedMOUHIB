# %%
class chien:
  def __init__(self,nom,race,age):
    self.nom=nom
    self.race=race
    self.age=age
  def aboyer(self):
    return "aboyer"
chien1=chien("rex","pitbull",3)
chien1.aboyer
# Out:
# <bound method chien.aboyer of <__main__.chien object at 0x7f6f555bb430>>
